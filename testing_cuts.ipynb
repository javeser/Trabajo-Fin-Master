# %%
import uproot 
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd
import seaborn as sns
import plotly.express as px
import pickle

# %%
signal_data = pd.read_pickle('data24.pkl')

print(signal_data)
# Out:
#            Jpsi_PT  L_END_VRHO  L_BPVDIRA    L_BPVIP  L_BPVIPCHI2  Lb_BPVDIRA  \
# 0      1530.080200  260.791412   1.000000   3.965463     0.242094    0.998844
# 1      2827.654541  401.730133   0.999993  26.149265    19.151312    0.999828
# 2      8226.013672  329.974548   0.999995  18.004717     8.549254    0.999854
# 3       965.858643  200.982803   0.999999   9.598845     4.414578    0.999807
# 4       765.989197  581.067444   1.000000   5.289914     1.241343    0.999958
# ...            ...         ...        ...        ...          ...         ...
# 10139  3679.229980  549.963928   0.999997  17.779921     7.560120    0.999897
# 10140   942.502808  437.730408   0.999996  18.308369     3.334865    0.999390
# 10141  4640.383789  410.616699   0.999994  22.579832    18.960491    0.997268
# 10142    82.539581  257.493622   0.999999   8.587435     1.243484    0.993781
# 10143  2156.298340  343.534332   0.999989  31.353951    10.748905    0.999619
#
# ...

# %%
# cuts = " (Jpsi_PT > 1000)& (Jpsi_MASS < 3150)& (Jpsi_MASS > 3000) & (Jpsi_P > 18000) &  (Jpsi_BPVDIRA > 0.999) & (Jpsi_MAXDOCA < 0.15)& (Jpsi_CHI2 < 4) & (L_END_VRHO > 150) &(L_END_VRHO < 600) & (L_BPVIP < 30) & (L_BPVDIRA > 0.9999) & (L_END_VZ > 5000) & (L_END_VZ < 8500) & (L_PT > 1000)& (L_P > 25000) & (L_MASS < 1200) & (Lb_MAXDOCA < 15) & (Lb_PT >2500) & (Lb_MINIPCHI2 < 10 ) & (Lb_BPVVDRHO > 0.1 ) & (Lb_CHI2 < 15) &  (mup_PID_MU > 3) & (mum_PID_MU > 3) & (mup_P > 10000)  & (mum_P > 10000) & (mum_MINIP > 0.1) & (mup_MINIP > 0.1) & (mum_MINIPCHI2 > 100) & (mup_MINIPCHI2 > 100) &  (mum_GHOSTPROB < 0.4) & (pim_P > 2000) & (pim_P < 500000) & (p_P > 10000)& (p_P < 500000) & (p_PT > 400) & (p_PID_P > 2)"
# # cuts = " (Jpsi_PT > 1000)& (Jpsi_MASS < 3150)& (Jpsi_MASS > 3000) & (Jpsi_P > 18000) & (Jpsi_END_VRHO > 1) & (Jpsi_BPVIP > 0.05) & (Jpsi_BPVDIRA > 0.999) & (Jpsi_MAXDOCA < 0.15)& (Jpsi_CHI2 < 4) & (L_END_VRHO > 150) &(L_END_VRHO < 600) & (L_BPVIP < 30) & (L_BPVDIRA > 0.9999) & (L_END_VZ > 5000) & (L_END_VZ < 8500) & (L_PT > 1000)& (L_P > 25000) & (L_MASS < 1200) & (Lb_MAXDOCA < 15) & (Lb_PT >2500) & (Lb_MINIPCHI2 < 10 ) & (Lb_BPVVDRHO > 0.1 ) & (Lb_CHI2 < 15) &  (mup_PID_MU > 3) & (mum_PID_MU > 3) & (mup_P > 10000) & (mup_PT > 600) & (mum_P > 10000) & (mum_PT > 600) & (mum_MINIP > 0.1) & (mup_MINIP > 0.1) & (mum_MINIPCHI2 > 100) & (mup_MINIPCHI2 > 100) &  (mum_GHOSTPROB < 0.4) & (pim_P > 2000) & (pim_P < 500000) & (p_P > 10000)& (p_P < 500000) & (p_PT > 400) & (p_PID_P > 2)"
# cut_MC = "(Cos_xi_L > 0.9999) & (Cos_xi_Lb > 0.99) & (Jpsi_PT > 1000) & (Jpsi_P > 18000) & (Jpsi_END_VRHO > 1) & (Jpsi_BPVIP > 0.05) & (Jpsi_BPVDIRA > 0.999) & (Jpsi_MAXDOCA < 0.15)& (Jpsi_CHI2 < 4) & (L_END_VRHO > 150) &(L_END_VRHO < 600) & (L_BPVIP < 30) & (L_BPVDIRA > 0.9999) & (L_END_VZ > 5000) & (L_END_VZ < 8500) & (L_PT > 1000)& (L_P > 25000) & (L_MASS < 1200) & (Lb_MAXDOCA < 15) & (Lb_PT >2500) & (Lb_MINIPCHI2 < 10 ) & (Lb_BPVVDRHO > 0.1 ) & (Lb_CHI2 < 15) &  (mup_PID_MU > 3) & (mum_PID_MU > 3) & (mup_P > 10000) & (mup_PT > 600) & (mum_P > 10000) & (mum_PT > 600) & (mum_MINIP > 0.1) & (mup_MINIP > 0.1) & (mum_MINIPCHI2 > 100) & (mup_MINIPCHI2 > 100) &  (mum_GHOSTPROB < 0.4) & (pim_P > 2000) & (pim_P < 500000) & (p_P > 10000)& (p_P < 500000) & (p_PT > 400) & (p_PID_P > 2)"
preselection_cut = '(Jpsi_P > 10000) & (mup_PID_MU > 0) & (mum_PID_MU > 0) & (Jpsi_MAXDOCA < 0.15) & (p_PID_P > 0) & ( p_P > 10000)& ( p_PT > 400) & ( pim_P > 2000) & (L_PT > 450) & (Lb_CHI2 < 150) & (L_MASS < 1500) & (L_MASS > 950) & (Jpsi_CHI2 < 4 ) &  (L_CHI2 < 100) '
preselection_cut_mc = '(Jpsi_P > 10000) & (mup_PID_MU > 0) & (mum_PID_MU > 0) & (Jpsi_MAXDOCA < 0.15) & (p_PID_P > 0) & ( p_P > 10000)& ( p_PT > 400) & ( pim_P > 2000) & (L_PT > 450) & (Lb_CHI2 < 150) & (L_MASS < 1500) & (L_MASS > 950) & (Jpsi_CHI2 < 4 ) &  (L_CHI2 < 100) '

# %%
signal_data_cut = signal_data.query(preselection_cut)
print(signal_data_cut)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /l/javeser/bdt_notebooks/.venv/lib/python3.10/site-packages/pandas/core/computation/scope.py:233, in Scope.resolve(self, key, is_local)
#     232 if self.has_resolvers:
# --> 233     return self.resolvers[key]
#     235 # if we're here that means that we have no locals and we also have
#     236 # no resolvers
#
# File /cvmfs/lhcbdev.cern.ch/conda/envs/default/2023-04-26_20-20/linux-64/lib/python3.10/collections/__init__.py:986, in ChainMap.__getitem__(self, key)
#     985         pass
# --> 986 return self.__missing__(key)
#
# File /cvmfs/lhcbdev.cern.ch/conda/envs/default/2023-04-26_20-20/linux-64/lib/python3.10/collections/__init__.py:978, in ChainMap.__missing__(self, key)
#     977 def __missing__(self, key):
# --> 978     raise KeyError(key)
#
# KeyError: 'mum_MINIP'
#
# ...
