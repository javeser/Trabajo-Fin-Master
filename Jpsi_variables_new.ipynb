# %%
import uproot 
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd
import seaborn as sns
import plotly.express as px

# %%
my_tuple = uproot.open("Lb2_JpsiLambda_vtx.root:Hlt2DetachedJpsiTuple/Tuple")

# %%
keys = ["Jpsi_END_VZ", "Jpsi_END_VX", "Jpsi_END_VY", "Jpsi_END_VRHO", "Jpsi_BPVCORRM", "Jpsi_BPVDIRA", "Jpsi_BPVETA", "Jpsi_BPVIPCHI2", "Jpsi_BPVFDCHI2", "Jpsi_BPVLTIME", "Jpsi_BPVFD", "Jpsi_BPVFDIRX", "Jpsi_BPVFDIRY", "Jpsi_BPVFDIRZ", "Jpsi_BPVFDVECX", "Jpsi_BPVFDVECY", "Jpsi_BPVFDVECZ", "Jpsi_BPVIP", "Jpsi_BPVVDRHO", "Jpsi_BPVVDX", "Jpsi_BPVVDY", "Jpsi_BPVVDZ", "Jpsi_COMB_MASS", "Jpsi_MAXDOCA", "Jpsi_MAXDOCACHI2", "Jpsi_MAXSDOCA", "Jpsi_MAXSDOCACHI2", "Jpsi_MASS", "Jpsi_P", "Jpsi_PT", "Jpsi_PX", "Jpsi_PY", "Jpsi_PZ", "Jpsi_E", "Jpsi_ETA", "Jpsi_PHI", "Jpsi_CHI2DOF", "Jpsi_CHI2", "Jpsi_FOURMOMENTUME", "Jpsi_FOURMOMENTUMX", "Jpsi_FOURMOMENTUMY", "Jpsi_FOURMOMENTUMZ"]

# %%
signal_montecarlo = my_tuple.arrays(keys,library="pd")
signal_montecarlo
# Out:
#        Jpsi_END_VZ  Jpsi_END_VX  Jpsi_END_VY  Jpsi_END_VRHO  Jpsi_BPVCORRM  \
# 0       -70.626801      -0.0091       0.2115       0.211696    4226.780762
# 1        85.263199       0.4022      -0.2261       0.461396    4231.889648
# 2        58.113098      -7.6754       2.4930       8.070118    5159.767090
# 3       126.555000      -2.3154       0.3172       2.337027    4990.095703
# 4       -25.339800      -0.6836      -0.2075       0.714399    5037.748535
# ...            ...          ...          ...            ...            ...
# 32619    33.887199       0.0880      -0.1434       0.168249    4921.671875
# 32620    33.887199       0.0880      -0.1434       0.168249    4921.671875
# 32621    39.195000      -0.0768      -0.1244       0.146197    4484.507324
# 32622    31.272800       0.1749      -0.5568       0.583623    5084.783691
# 32623   118.604301      -0.1267      -0.1662       0.208986    3801.375244
#
#        Jpsi_BPVDIRA  Jpsi_BPVETA  Jpsi_BPVIPCHI2  Jpsi_BPVFDCHI2  \
# ...

# %%
import matplotlib.pyplot as plt

num_bins = 100

# Configuración de la figura y ejes
fig, axes = plt.subplots(nrows=11, ncols=4, figsize=(20, 40))

# Iterar sobre las variables y graficar un histograma para cada una
for i, variable in enumerate(keys):
    row = i // 4
    col = i % 4
    ax = axes[row, col]
    ax.hist(signal_montecarlo[variable], bins=num_bins, color='blue', alpha=0.7)
    ax.set_xlabel(variable)
    ax.set_ylabel('Entries')
    ax.set_title('Histograma de {}'.format(variable))

plt.tight_layout()
plt.show()

# %%
signal_montecarlo = my_tuple.arrays(keys+ ['Jpsi_BKGCAT'])

# %%
def Jpsi_variables():
    # Abrir el archivo ROOT y obtener el árbol
    filename = "Lb2_JpsiLambda_vtx.root"
    tree = uproot.open(filename)["Hlt2DetachedJpsiTuple/Tuple"]

    # Obtener los nombres de las ramas del árbol
    branch_names = tree.keys()

    # Definir variables para almacenar los nombres filtrados
    filtered_names = []

    # Loop sobre todas las ramas
    for name in branch_names:
        # Verificar si la variable contiene ciertas palabras clave
        if any(keyword in name for keyword in ["Jpsi_END_VZ", "Jpsi_END_VX", "Jpsi_END_VY", "Jpsi_END_VRHO", "Jpsi_BPVCORRM", "Jpsi_BPVDIRA", 
                                               "Jpsi_BPVETA", "Jpsi_BPVIPCHI2", "Jpsi_BPVFDCHI2", "Jpsi_BPVLTIME", "Jpsi_BPVFD", "Jpsi_BPVFDIRX", 
                                               "Jpsi_BVPFDIRY", "Jpsi_BPVDIRZ", "Jpsi_BPVFDVECX", "Jpsi_BPVFDVECY", "Jpsi_BPVFDVECZ", "Jpsi_BPVIP", 
                                               "Jpsi_BPVVRHO", "Jpsi_BPVVDX", "Jpsi_BPVVDY", "Jpsi_BPVVDZ", "Jpsi_COMB_MASS", "Jpsi_MAXDOCA", "Jpsi_MAXDOCACHI2", 
                                               "Jpsi_MAXSDOCA", "Jpsi_MAXSDOCACHI2", "Jpsi_MASS", "Jpsi_P", "Jpsi_PT", "Jpsi_PX", "Jpsi_PY", "Jpsi_PZ", "Jpsi_E", 
                                               "Jpsi_ETA", "Jpsi_PHI", "Jpsi_CHI2DOF", "Jpsi_CHI2", "Jpsi_FOURMOMENTUME", "Jpsi_FOURMOMENTUMX", "Jpsi_FOURMOMENTUMY", 
                                               "Jpsi_FOURMOMENTUMZ","mu_minus_PID_P","mu_minus_PID_PI","mu_minus_PID_K","mu_minus_PID_MU","mu_minus_PID_E","mu_plus_PID_P",
                                               "mu_plus_PID_PI","mu_plus_PID_K","mu_plus_PID_MU","mu_plus_PID_E","mu_plus_GHOSTPROB", "mu_plus_MINIP","mu_plus_MINIPCHI2", "mu_plus_P", "mu_plus_PT", "mu_plus_CHI2",
                                               "mu_minus_GHOSTPROB", "mu_minus_MINIP","mu_minus_MINIPCHI2", "mu_minus_P", "mu_minus_PT", "mu_minus_CHI2"]):
            filtered_names.append(name)

    # Determinar el número de filas y columnas para el lienzo
    rows = 4
    cols = 3

    # Variables contadoras para el lienzo y el histograma
    canv_count = 0
    hist_count = 0
    
    log_bins = {
    "Jpsi_END_VRHO": np.logspace(np.log10(10e-3),np.log10(10),50),
    "Jpsi_BPVCORRM": np.logspace(np.log10(10e2),np.log10(10e4),50),
    "Jpsi_BPVIPCHI2": np.logspace(np.log10(10e-3),np.log10(10e2),50),
    "Jpsi_BPVFDCHI2": np.logspace(np.log10(10e-1),np.log10(10e4),50),
    "Jpsi_BPVFD": np.logspace(np.log10(10e-3),np.log10(10e2),50),
    "Jpsi_BPVIP": np.logspace(np.log10(10e-4),np.log10(1),50),
    "Jpsi_BPVVDZ": np.logspace(np.log10(10e-2),np.log10(10e2),50),
    "Jpsi_MAXSDOCACHI2": np.logspace(np.log10(10e-7),np.log10(10e1),50),
    "Jpsi_MAXDOCACHI2": np.logspace(np.log10(10e-7),np.log10(10e1),50),
    "Jpsi_CHI2DOF": np.logspace(np.log10(10e-6),np.log10(10e-1),50),
    "Jpsi_CHI2": np.logspace(np.log10(10e-6),np.log10(10e-1),50),
    "mu_plus_MINIPCHI2": np.logspace(np.log10(10e-4),np.log10(10e2),40),
    "mu_minus_MINIPCHI2": np.logspace(np.log10(10e-4),np.log10(10e2),50),
    "mu_plus_GHOSTPROB": np.logspace(np.log10(10e-6),np.log10(10e0),50),
    "mu_plus_MINIP": np.logspace(np.log10(10e-4),np.log10(10e0),50),
    "mu_minus_MINIP": np.logspace(np.log10(10e-4),np.log10(10e0),50),
    }

    lin_bins = {
    "Jpsi_END_VZ" : np.linspace(-300,400,100), 
    "Jpsi_END_VX" : np.linspace(-4,4,100),
    "Jpsi_END_VY": np.linspace(-4,4,100),  
    "Jpsi_BPVDIRA": np.linspace(0.99,1.005,100), 
    "Jpsi_BPVETA": np.linspace(-0,8,100), 
    "Jpsi_BPVLTIME": np.linspace(-4,4,100), 
    "Jpsi_BPVFDIRX": np.linspace(-0.5,0.5,100), 
    "Jpsi_BPVFDIRY": np.linspace(-0.4,0.4,100),  
    "Jpsi_BPVFDIRZ": np.linspace(0.96,1.01,100), 
    "Jpsi_BPVFDVECX": np.linspace(-3,3,100), 
    "Jpsi_BPVFDVECY": np.linspace(-3,3,100), 
    "Jpsi_BPVFDVECZ": np.linspace(-2,65,100),  
    "Jpsi_BPVVRHO": np.linspace(-0,4.5,100), 
    "Jpsi_BPVVDX": np.linspace(-3,3,100), 
    "Jpsi_BPVVDY": np.linspace(-3,3,100), 
    "Jpsi_BPVVDZ": np.linspace(-0.2,80,100), 
    "Jpsi_COMB_MASS": np.linspace(2940,3200,100), 
    "Jpsi_MAXDOCA": np.linspace(-0,0.2,100),
    "Jpsi_MAXSDOCA": np.linspace(-0,0.2,100), 
    "Jpsi_MASS": np.linspace(2940,3200,100), 
    "Jpsi_P": np.linspace(0,400000,100), 
    "Jpsi_PT": np.linspace(0,25000,100), 
    "Jpsi_PX": np.linspace(-30000,30000,100), 
    "Jpsi_PY": np.linspace(-20000,20000,100), 
    "Jpsi_PZ": np.linspace(0,600000,100), 
    "Jpsi_E": np.linspace(0,600000,100), 
    "Jpsi_ETA": np.linspace(0,8,100), 
    "Jpsi_PHI": np.linspace(-3.7,3.7,100), 
    "Jpsi_FOURMOMENTUME": np.linspace(0,600000,100), 
    "Jpsi_FOURMOMENTUMX": np.linspace(-30000,30000,100), 
    "Jpsi_FOURMOMENTUMY": np.linspace(-20000,20000,100), 
    "Jpsi_FOURMOMENTUMZ": np.linspace(0,600000,100),
    "mu_minus_PID_P": np.linspace(-300,60,100),
    "mu_minus_PID_PI": np.linspace(-1,1,100),
    "mu_minus_PID_K": np.linspace(-300,60,100),
    "mu_minus_PID_MU": np.linspace(-7,20,100),
    "mu_minus_PID_E": np.linspace(-15,6,100),
    "mu_plus_PID_P": np.linspace(-300,70,100),
    "mu_plus_PID_PI": np.linspace(-1,1,100),
    "mu_plus_PID_K": np.linspace(-250,60,100),
    "mu_plus_PID_MU": np.linspace(-7,20,100),
    "mu_plus_PID_E": np.linspace(-15,6,100),
    "mu_plus_P": np.linspace(0,400000,100), 
    "mu_plus_PT": np.linspace(0,20000,100),
    "mu_plus_PX": np.linspace(-20000,20000,100),
    "mu_plus_PY": np.linspace(-20000,20000,100),
    "mu_plus_PZ": np.linspace(-0,400000,100),
    "mu_plus_PHI": np.linspace(-4,4,100),
    "mu_plus_CHI2DOF": np.linspace(0,3,100),
    "mu_plus_CHI2": np.linspace(0,100,100),
    "mu_minus_MINIPCHI2": np.linspace(-4,4,100), 
    "mu_minus_P": np.linspace(0,400000,100),
    "mu_minus_PX": np.linspace(-15000,20000,100),
    "mu_minus_PY": np.linspace(-15000,15000,100),
    "mu_minus_PZ": np.linspace(0,300000,100),
    "mu_minus_PT": np.linspace(-0,15000,100),
    "mu_minus_PHI": np.linspace(-4,4,100),
    "mu_minus_CHI2DOF": np.linspace(0,3,100),
    "mu_minus_CHI2": np.linspace(0,100,100),
    "mu_minus_GHOSTPROB":  np.linspace(0,0.4,100)
    }
    # Loop sobre los nombres de las variables filtradas
    for i, var in enumerate(filtered_names):
        # Obtener los datos de la variable de la rama específica
        data = tree[var].array()

        # Obtener los datos para Jpsiseñal y fondo
        bkgs = data[tree["Jpsi_BKGCAT"].array() != 0]
        signals = data[tree["Jpsi_BKGCAT"].array() == 0]

        # Crear un nuevo lienzo cada cols*rows histogramas
        if hist_count % (rows * cols) == 0:
            canv_count += 1
            plt.figure(figsize=(16, 15))

        # Trazar histogramas
        plt.subplot(rows, cols, hist_count % (rows * cols) + 1)

        if var in ["Jpsi_END_VRHO", "Jpsi_BPVCORRM", "Jpsi_BPVIPCHI2","Jpsi_BPVFDCHI2", "Jpsi_BPVFD", "Jpsi_BPVIP", "Jpsi_BPVVDZ", "Jpsi_MAXSDOCACHI2", "Jpsi_MAXDOCACHI2", "Jpsi_CHI2DOF", "Jpsi_CHI2","mu_plus_MINIPCHI2","mu_minus_MINIPCHI2","mu_plus_GHOSTPROB","mu_plus_MINIP", "mu_minus_MINIP"]:
            plt.hist(bkgs, bins=log_bins[var], color='red', alpha=0.5, label='Background', histtype='step', density=True)
            plt.hist(signals, bins=log_bins[var], color='blue', alpha=0.5, label='Signal', histtype='step', density=True)
            plt.xscale('log')
        else:
            if var in ["Jpsi_BPVDIRA"]:#, "Jpsi_BPVFDIRZ"]:
                plt.hist(bkgs, bins=lin_bins[var], color='red', alpha=0.5, label='Background', histtype='step', density=True)
                plt.hist(signals, bins=lin_bins[var], color='blue', alpha=0.5, label='Signal', histtype='step', density=True)
                plt.yscale('log')
            else:
                plt.hist(bkgs, bins=lin_bins[var], color='red', alpha=0.5, label='Background', histtype='step', density=True)
                plt.hist(signals, bins=lin_bins[var], color='blue', alpha=0.5, label='Signal', histtype='step', density=True)
        
        plt.xlabel(var)
        plt.ylabel('Entries')
        plt.legend()

        # Establecer escala logarítmica para ciertas variables
        

        hist_count += 1

    plt.show()

Jpsi_variables()

# %%
my_tuple1 = uproot.open("00222479_00000001_1.data_turbopass_bandq_lb2jpsilmd.root:Hlt2BandQ_Lb2JpsiLambdaTT/DecayTree;1")
my_tuple2 = uproot.open("00222479_00000002_1.data_turbopass_bandq_lb2jpsilmd.root:Hlt2BandQ_Lb2JpsiLambdaTT/DecayTree;1")
my_tuple3 = uproot.open("00222479_00000003_1.data_turbopass_bandq_lb2jpsilmd.root:Hlt2BandQ_Lb2JpsiLambdaTT/DecayTree;1")
my_tuple4 = uproot.open("00222479_00000004_1.data_turbopass_bandq_lb2jpsilmd.root:Hlt2BandQ_Lb2JpsiLambdaTT/DecayTree;1")
my_tuple5 = uproot.open("00222479_00000005_1.data_turbopass_bandq_lb2jpsilmd.root:Hlt2BandQ_Lb2JpsiLambdaTT/DecayTree;5")
my_tuple6 = uproot.open("00222479_00000005_1.data_turbopass_bandq_lb2jpsilmd.root:Hlt2BandQ_Lb2JpsiLambdaTT/DecayTree;5")
my_tuple7 = uproot.open("00222479_00000005_1.data_turbopass_bandq_lb2jpsilmd.root:Hlt2BandQ_Lb2JpsiLambdaTT/DecayTree;5")
my_tuple8 = uproot.open("00222479_00000005_1.data_turbopass_bandq_lb2jpsilmd.root:Hlt2BandQ_Lb2JpsiLambdaTT/DecayTree;5")
my_tuple9 = uproot.open("00222479_00000005_1.data_turbopass_bandq_lb2jpsilmd.root:Hlt2BandQ_Lb2JpsiLambdaTT/DecayTree;5")

# %%
keys2 = ["Jpsi_END_VZ", "Jpsi_END_VX", "Jpsi_END_VY", "Jpsi_END_VRHO", "Jpsi_BPVCORRM", "Jpsi_BPVDIRA", "Jpsi_BPVETA", "Jpsi_BPVIPCHI2", "Jpsi_BPVFDCHI2", 
         "Jpsi_BPVLTIME", "Jpsi_BPVFD", "Jpsi_BPVFDIRX", "Jpsi_BPVFDIRY", "Jpsi_BPVFDIRZ", "Jpsi_BPVFDVECX", "Jpsi_BPVFDVECY", "Jpsi_BPVFDVECZ", "Jpsi_BPVIP", 
         "Jpsi_BPVVDRHO", "Jpsi_BPVVDX", "Jpsi_BPVVDY", "Jpsi_BPVVDZ", "Jpsi_MAXDOCA", "Jpsi_MAXDOCACHI2", "Jpsi_MASS", "Jpsi_P", "Jpsi_PT", "Jpsi_PX", "Jpsi_PY", 
         "Jpsi_PZ", "Jpsi_ETA", "Jpsi_PHI", "Jpsi_CHI2DOF", "Jpsi_CHI2", "Jpsi_FOURMOMENTUME", "Jpsi_FOURMOMENTUMX", "Jpsi_FOURMOMENTUMY", "Jpsi_FOURMOMENTUMZ"]

# %%
keys3_MC = ["Jpsi_END_VZ", "Jpsi_END_VX", "Jpsi_END_VY", "Jpsi_END_VRHO", "Jpsi_BPVCORRM", "Jpsi_BPVDIRA", 
                                               "Jpsi_BPVETA", "Jpsi_BPVIPCHI2", "Jpsi_BPVFDCHI2", "Jpsi_BPVLTIME", "Jpsi_BPVFD", "Jpsi_BPVFDIRX", 
                                               "Jpsi_BVPFDIRY", "Jpsi_BPVDIRZ", "Jpsi_BPVFDVECX", "Jpsi_BPVFDVECY", "Jpsi_BPVFDVECZ", "Jpsi_BPVIP", 
                                               "Jpsi_BPVVRHO", "Jpsi_BPVVDX", "Jpsi_BPVVDY", "Jpsi_BPVVDZ", "Jpsi_COMB_MASS", "Jpsi_MAXDOCA", "Jpsi_MAXDOCACHI2", 
                                               "Jpsi_MAXSDOCA", "Jpsi_MAXSDOCACHI2", "Jpsi_MASS", "Jpsi_P", "Jpsi_PT", "Jpsi_PX", "Jpsi_PY", "Jpsi_PZ",
                                               "Jpsi_ETA", "Jpsi_PHI", "Jpsi_CHI2DOF", "Jpsi_CHI2", "Jpsi_FOURMOMENTUME", "Jpsi_FOURMOMENTUMX", "Jpsi_FOURMOMENTUMY", 
                                               "Jpsi_FOURMOMENTUMZ","mu_minus_PID_P","mu_minus_PID_PI","mu_minus_PID_K","mu_minus_PID_MU","mu_minus_PID_E","mu_plus_PID_P",
                                               "mu_plus_PID_PI","mu_plus_PID_K","mu_plus_PID_MU","mu_plus_PID_E","mu_plus_GHOSTPROB", "mu_plus_MINIP","mu_plus_MINIPCHI2", "mu_plus_P", "mu_plus_PT", "mu_plus_CHI2",
                                               "mu_minus_GHOSTPROB", "mu_minus_MINIP","mu_minus_MINIPCHI2", "mu_minus_P", "mu_minus_PT", "mu_minus_CHI2"]

# %%
keys3 = ["Jpsi_END_VZ", "Jpsi_END_VX", "Jpsi_END_VY", "Jpsi_END_VRHO", "Jpsi_BPVCORRM", "Jpsi_BPVDIRA", "Jpsi_BPVETA", "Jpsi_BPVIPCHI2", "Jpsi_BPVFDCHI2", 
         "Jpsi_BPVLTIME", "Jpsi_BPVFD", "Jpsi_BPVFDIRX", "Jpsi_BPVFDIRY", "Jpsi_BPVFDIRZ", "Jpsi_BPVFDVECX", "Jpsi_BPVFDVECY", "Jpsi_BPVFDVECZ", "Jpsi_BPVIP", 
         "Jpsi_BPVVDRHO", "Jpsi_BPVVDX", "Jpsi_BPVVDY", "Jpsi_BPVVDZ", "Jpsi_MAXDOCA", "Jpsi_MAXDOCACHI2", "Jpsi_MASS", "Jpsi_P", "Jpsi_PT", "Jpsi_PX", "Jpsi_PY", 
         "Jpsi_PZ", "Jpsi_ETA", "Jpsi_PHI", "Jpsi_CHI2DOF", "Jpsi_CHI2", "Jpsi_FOURMOMENTUME", "Jpsi_FOURMOMENTUMX", "Jpsi_FOURMOMENTUMY", "Jpsi_FOURMOMENTUMZ","mup_PID_P","mup_PID_K","mup_PID_PI","mup_PID_MU","mup_PID_E",
         "mup_GHOSTPROB","mup_MINIP", "mup_MINIPCHI2", "mup_P","mup_PT","mup_PX","mup_PY","mup_PZ","mup_PHI", "mup_CHI2DOF", "mup_CHI2", "mum_PID_P","mum_PID_K","mum_PID_PI","mum_PID_MU","mum_PID_E",
         "mum_GHOSTPROB","mum_MINIP", "mum_MINIPCHI2", "mum_P","mum_PT","mum_PX","mum_PY","mum_PZ","mum_PHI", "mum_CHI2DOF", "mum_CHI2"]

# %%
signal_data1 = my_tuple1.arrays(keys3,library="pd")
signal_data2 = my_tuple2.arrays(keys3,library="pd")
signal_data3 = my_tuple3.arrays(keys3,library="pd")
signal_data4 = my_tuple4.arrays(keys3,library="pd")
signal_data5 = my_tuple5.arrays(keys3,library="pd")
#signal_data6 = my_tuple6.arrays(keys3,library="pd")
#signal_data7 = my_tuple7.arrays(keys3,library="pd")
#signal_data8 = my_tuple8.arrays(keys3,library="pd")
#signal_data9 = my_tuple9.arrays(keys3,library="pd")

# %%
signal_data12 = pd.merge(signal_data1,signal_data2, how="outer")
signal_data34 = pd.merge(signal_data3,signal_data4, how="outer")
signal_data345 = pd.merge(signal_data34,signal_data5, how="outer")
#signal_data56 = pd.merge(signal_data5,signal_data6, how="outer")
#signal_data78 = pd.merge(signal_data7,signal_data8, how="outer")
#signal_data789 = pd.merge(signal_data78,signal_data9, how="outer")

signal_data12345 = pd.merge(signal_data12,signal_data345, how="outer")
#signal_data56789 = pd.merge(signal_data56,signal_data789, how="outer")

#signal_data =  pd.merge(signal_data1234,signal_data56789, how="outer")

signal_data =  signal_data12345

# %%
signal_data
# Out:
#           Jpsi_END_VZ  Jpsi_END_VX  Jpsi_END_VY  Jpsi_END_VRHO  Jpsi_BPVCORRM  \
# 0           61.592701       1.2069       0.1160       1.212462    6693.918945
# 1           -9.427900       1.0965       0.1034       1.101364    7168.196289
# 2            6.024500       1.0256       0.0333       1.026140    3831.641602
# 3           53.905701       0.9342      -0.0779       0.937442    4055.289551
# 4           53.905701       0.9342      -0.0779       0.937442    4055.289551
# ...               ...          ...          ...            ...            ...
# 15878497   -19.596100       0.9307      -0.0524       0.932174    3830.667725
# 15878498   -19.596100       0.9307      -0.0524       0.932174    3830.667725
# 15878499   -19.596100       0.9307      -0.0524       0.932174    3830.667725
# 15878500   -19.596100       0.9307      -0.0524       0.932174    3830.667725
# 15878501   -19.596100       0.9307      -0.0524       0.932174    3830.667725
#
# ...

# %%
def Jpsi_variables():
    # Abrir el archivo ROOT y obtener el árbol
    filename = "Lb2_JpsiLambda_vtx.root"
    tree = uproot.open(filename)["Hlt2DetachedJpsiTuple/Tuple"]

    # Obtener los nombres de las ramas del árbol
    branch_names = tree.keys()

    # Definir variables para almacenar los nombres filtrados
    filtered_names = []


    # Loop sobre los nombres de las variables filtradas
    for i, var in enumerate(filtered_names):
        # Obtener los datos de la variable de la rama específica
        data = tree[var].array()

        # Obtener los datos para Jpsiseñal y fondo
        bkgs = data[tree["Jpsi_BKGCAT"].array() != 0]
        signals = data[tree["Jpsi_BKGCAT"].array() == 0]

        # Crear un nuevo lienzo cada cols*rows histogramas
        if hist_count % (rows * cols) == 0:
            canv_count += 1
            plt.figure(figsize=(16, 15))

        # Trazar histogramas
        plt.subplot(rows, cols, hist_count % (rows * cols) + 1)

        if var in ["Jpsi_END_VRHO", "Jpsi_BPVCORRM", "Jpsi_BPVIPCHI2","Jpsi_BPVFDCHI2", "Jpsi_BPVFD", "Jpsi_BPVIP", "Jpsi_BPVVDZ", "Jpsi_MAXSDOCACHI2", "Jpsi_MAXDOCACHI2", "Jpsi_CHI2DOF", "Jpsi_CHI2","mu_plus_MINIPCHI2","mu_minus_MINIPCHI2","mu_plus_GHOSTPROB","mu_plus_MINIP", "mu_minus_MINIP"]:
            plt.hist(bkgs, bins=log_bins[var], color='red', alpha=0.5, label='Background', histtype='step', density=True)
            plt.hist(signals, bins=log_bins[var], color='blue', alpha=0.5, label='Signal', histtype='step', density=True)
            plt.xscale('log')
        else:
            if var in ["Jpsi_BPVDIRA"]:#, "Jpsi_BPVFDIRZ"]:
                plt.hist(bkgs, bins=lin_bins[var], color='red', alpha=0.5, label='Background', histtype='step', density=True)
                plt.hist(signals, bins=lin_bins[var], color='blue', alpha=0.5, label='Signal', histtype='step', density=True)
                plt.yscale('log')
            else:
                plt.hist(bkgs, bins=lin_bins[var], color='red', alpha=0.5, label='Background', histtype='step', density=True)
                plt.hist(signals, bins=lin_bins[var], color='blue', alpha=0.5, label='Signal', histtype='step', density=True)
        
        plt.xlabel(var)
        plt.ylabel('Entries')
        plt.legend()

        # Establecer escala logarítmica para ciertas variables
        

        hist_count += 1

    plt.show()

Jpsi_variables()

# %%
def Jpsi_variables():
    # Abrir el archivo ROOT y obtener el árbol
    filename = "Lb2_JpsiLambda_vtx.root"
    tree = uproot.open(filename)["Hlt2DetachedJpsiTuple/Tuple"]

    # Obtener los nombres de las ramas del árbol
    branch_names = tree.keys()

    # Definir variables para almacenar los nombres filtrados
    filtered_names = []

    # Loop sobre todas las ramas
    for name in branch_names:
        # Verificar si la variable contiene ciertas palabras clave
        if any(keyword in name for keyword in ["Jpsi_END_VZ", "Jpsi_END_VX", "Jpsi_END_VY", "Jpsi_END_VRHO", "Jpsi_BPVCORRM", "Jpsi_BPVDIRA", "Jpsi_BPVETA", "Jpsi_BPVIPCHI2", "Jpsi_BPVFDCHI2", "Jpsi_BPVLTIME", "Jpsi_BPVFD", "Jpsi_BPVFDIRX", "Jpsi_BVPFDIRY", "Jpsi_BPVDIRZ", "Jpsi_BPVFDVECX", "Jpsi_BPVFDVECY", "Jpsi_BPVFDVECZ", "Jpsi_BPVIP", "Jpsi_BPVVRHO", "Jpsi_BPVVDX", "Jpsi_BPVVDY", "Jpsi_BPVVDZ", "Jpsi_COMB_MASS", "Jpsi_MAXDOCA", "Jpsi_MAXDOCACHI2", "Jpsi_MAXSDOCA", "Jpsi_MAXSDOCACHI2", "Jpsi_MASS", "Jpsi_P", "Jpsi_PT", "Jpsi_PX", "Jpsi_PY", "Jpsi_PZ", "Jpsi_E", "Jpsi_ETA", "Jpsi_PHI", "Jpsi_CHI2DOF", "Jpsi_CHI2", "Jpsi_FOURMOMENTUME", "Jpsi_FOURMOMENTUMX", "Jpsi_FOURMOMENTUMY", "Jpsi_FOURMOMENTUMZ"]):
            filtered_names.append(name)

    # Determinar el número de filas y columnas para el lienzo
    rows = 4
    cols = 3

    # Variables contadoras para el lienzo y el histograma
    canv_count = 0
    hist_count = 0
    
    log_bins = {
    "Jpsi_END_VRHO" : np.logspace(np.log10(10e-3),np.log10(10e1)),
    "Jpsi_BPVCORRM": np.logspace(np.log10(10e3),np.log10(10e5)),
    "Jpsi_BPVDIRA": np.logspace(np.log10(10e-1),np.log10(10)),
    "Jpsi_BPVIPCHI2": np.logspace(np.log10(10e-1),np.log10(10e2)),
    "Jpsi_BPVFDCHI2": np.logspace(np.log10(10e-1),np.log10(10e5)),
    "Jpsi_BPVFD": np.logspace(np.log10(10e-1),np.log10(10e2)),
    "Jpsi_BPVIP": np.logspace(np.log10(10e-3),np.log10(10)),
    "Jpsi_BPVVDZ": np.logspace(np.log10(10e-1),np.log10(10e3)),
    "Jpsi_MAXSDOCACHI2": np.logspace(np.log10(10e-5),np.log10(10e2)),
    "Jpsi_MAXDOCACHI2": np.logspace(np.log10(10e-5),np.log10(10e2)),
    "Jpsi_CHI2DOF": np.logspace(np.log10(10e-5),np.log10(10e1)),
    "Jpsi_CHI2": np.logspace(np.log10(10e-5),np.log10(10e1))
    }
    # Loop sobre los nombres de las variables filtradas
    for i, var in enumerate(keys2):
        # Obtener los datos de la variable de la rama específica
        data = tree[var].array()

        # Obtener los datos para señal y fondo
        bkg = data[tree["Jpsi_BKGCAT"].array() != 0]

        # Crear un nuevo lienzo cada cols*rows histogramas
        if hist_count % (rows * cols) == 0:
            canv_count += 1
            plt.figure(figsize=(16, 15))

        # Trazar histogramas
        plt.subplot(rows, cols, hist_count % (rows * cols) + 1)

        if var in ["Jpsi_END_VRHO", "Jpsi_BPVCORRM", "Jpsi_BPVDIRA", "Jpsi_BPVIPCHI2","Jpsi_BPVFDCHI2", "Jpsi_BPVFD", "Jpsi_BPVIP", "Jpsi_BPVVDZ", "Jpsi_MAXSDOCACHI2", "Jpsi_MAXDOCACHI2", "Jpsi_CHI2DOF", "Jpsi_CHI2"]:
            plt.hist(signal_data[var], bins=log_bins[var], color='red', alpha=0.5, label='Data', histtype='step', density=True)
            plt.hist(bkg, bins=log_bins[var], color='blue', alpha=0.5, label='MC_Background', histtype='step', density=True)
            plt.xscale('log')
        else:
            plt.hist(signal_data[var], bins=100, color='red', alpha=0.5, label='Data', histtype='step', density=True)
            plt.hist(bkg, bins=100, color='blue', alpha=0.5, label='MC_Background', histtype='step', density=True)
        
        plt.xlabel(var)
        plt.ylabel('Entries')
        plt.legend()
        hist_count += 1

    plt.show()

Jpsi_variables()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 71
#      67         hist_count += 1
#      69     plt.show()
# ---> 71 Jpsi_variables()
#
# Cell In[4], line 4, in Jpsi_variables()
#       1 def Jpsi_variables():
#       2     # Abrir el archivo ROOT y obtener el árbol
#       3     filename = "Lb2_JpsiLambda_vtx.root"
# ----> 4     tree = uproot.open(filename)["Hlt2DetachedJpsiTuple/Tuple"]
#       6     # Obtener los nombres de las ramas del árbol
#       7     branch_names = tree.keys()
#
# NameError: name 'uproot' is not defined

# %%
def Jpsi_variables():
    # Abrir el archivo ROOT y obtener el árbol
    filename = "Lb2_JpsiLambda_vtx.root"
    tree = uproot.open(filename)["Hlt2DetachedJpsiTuple/Tuple"]

    # Obtener los nombres de las ramas del árbol
    branch_names = tree.keys()

    # Definir variables para almacenar los nombres filtrados
    filtered_names = []

    # Loop sobre todas las ramas
    for name in branch_names:
        # Verificar si la variable contiene ciertas palabras clave
        if any(keyword in name for keyword in ["Jpsi_END_VZ", "Jpsi_END_VX", "Jpsi_END_VY", "Jpsi_END_VRHO", "Jpsi_BPVCORRM", "Jpsi_BPVDIRA", "Jpsi_BPVETA", "Jpsi_BPVIPCHI2", "Jpsi_BPVFDCHI2", "Jpsi_BPVLTIME", "Jpsi_BPVFD", "Jpsi_BPVFDIRX", "Jpsi_BVPFDIRY", "Jpsi_BPVDIRZ", "Jpsi_BPVFDVECX", "Jpsi_BPVFDVECY", "Jpsi_BPVFDVECZ", "Jpsi_BPVIP", "Jpsi_BPVVRHO", "Jpsi_BPVVDX", "Jpsi_BPVVDY", "Jpsi_BPVVDZ", "Jpsi_COMB_MASS", "Jpsi_MAXDOCA", "Jpsi_MAXDOCACHI2", "Jpsi_MAXSDOCA", "Jpsi_MAXSDOCACHI2", "Jpsi_MASS", "Jpsi_P", "Jpsi_PT", "Jpsi_PX", "Jpsi_PY", "Jpsi_PZ", "Jpsi_E", "Jpsi_ETA", "Jpsi_PHI", "Jpsi_CHI2DOF", "Jpsi_CHI2", "Jpsi_FOURMOMENTUME", "Jpsi_FOURMOMENTUMX", "Jpsi_FOURMOMENTUMY", "Jpsi_FOURMOMENTUMZ"]):
            filtered_names.append(name)

    # Determinar el número de filas y columnas para el lienzo
    rows = 4
    cols = 3

    # Variables contadoras para el lienzo y el histograma
    canv_count = 0
    hist_count = 0
    
    log_bins = {
    "Jpsi_END_VRHO" : np.logspace(np.log10(10e-3),np.log10(10e1)),
    "Jpsi_BPVCORRM": np.logspace(np.log10(10e3),np.log10(10e5)),
    "Jpsi_BPVDIRA": np.logspace(np.log10(10e-1),np.log10(10)),
    "Jpsi_BPVIPCHI2": np.logspace(np.log10(10e-1),np.log10(10e2)),
    "Jpsi_BPVFDCHI2": np.logspace(np.log10(10e-1),np.log10(10e5)),
    "Jpsi_BPVFD": np.logspace(np.log10(10e-1),np.log10(10e2)),
    "Jpsi_BPVIP": np.logspace(np.log10(10e-3),np.log10(10)),
    "Jpsi_BPVVDZ": np.logspace(np.log10(10e-1),np.log10(10e3)),
    "Jpsi_MAXSDOCACHI2": np.logspace(np.log10(10e-5),np.log10(10e2)),
    "Jpsi_MAXDOCACHI2": np.logspace(np.log10(10e-5),np.log10(10e2)),
    "Jpsi_CHI2DOF": np.logspace(np.log10(10e-5),np.log10(10e1)),
    "Jpsi_CHI2": np.logspace(np.log10(10e-5),np.log10(10e1))
    }
    # Loop sobre los nombres de las variables filtradas
    for i, var in enumerate(keys2):
        # Obtener los datos de la variable de la rama específica
        data = tree[var].array()

        # Obtener los datos para señal y fondo
        bkg = data[tree["Jpsi_BKGCAT"].array() == 0]

        # Crear un nuevo lienzo cada cols*rows histogramas
        if hist_count % (rows * cols) == 0:
            canv_count += 1
            plt.figure(figsize=(16, 15))

        # Trazar histogramas
        plt.subplot(rows, cols, hist_count % (rows * cols) + 1)

        if var in ["Jpsi_END_VRHO", "Jpsi_BPVCORRM", "Jpsi_BPVDIRA", "Jpsi_BPVIPCHI2","Jpsi_BPVFDCHI2", "Jpsi_BPVFD", "Jpsi_BPVIP", "Jpsi_BPVVDZ", "Jpsi_MAXSDOCACHI2", "Jpsi_MAXDOCACHI2", "Jpsi_CHI2DOF", "Jpsi_CHI2"]:
            plt.hist(signal_data[var], bins=log_bins[var], color='red', alpha=0.5, label='Data', histtype='step', density=True)
            plt.hist(bkg, bins=log_bins[var], color='blue', alpha=0.5, label='MC_Background', histtype='step', density=True)
            plt.xscale('log')
        else:
            plt.hist(signal_data[var], bins=100, color='red', alpha=0.5, label='Data', histtype='step', density=True)
            plt.hist(bkg, bins=100, color='blue', alpha=0.5, label='MC_Background', histtype='step', density=True)
        
        plt.xlabel(var)
        plt.ylabel('Entries')
        plt.legend()
        hist_count += 1

    plt.show()

Jpsi_variables()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 71
#      67         hist_count += 1
#      69     plt.show()
# ---> 71 Jpsi_variables()
#
# Cell In[1], line 4, in Jpsi_variables()
#       1 def Jpsi_variables():
#       2     # Abrir el archivo ROOT y obtener el árbol
#       3     filename = "Lb2_JpsiLambda_vtx.root"
# ----> 4     tree = uproot.open(filename)["Hlt2DetachedJpsiTuple/Tuple"]
#       6     # Obtener los nombres de las ramas del árbol
#       7     branch_names = tree.keys()
#
# NameError: name 'uproot' is not defined
