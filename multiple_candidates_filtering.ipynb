# %%
import uproot 
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd
import seaborn as sns
import plotly.express as px
from matplotlib import colors
import math as math
from sklearn.model_selection import train_test_split
from catboost import CatBoostClassifier, Pool
from catboost.utils import get_roc_curve

# %%
mc_signal_AP = pd.read_pickle('AP_filter_mc_data.pkl')
data24_AP = pd.read_pickle('AP_filter_data24.pkl')

# %%
mc_data24_selected_chi2  = mc_signal_AP[mc_signal_AP.groupby(['EVENTNUMBER']).transform('min','SUMCHI2')['SUMCHI2']==mc_signal_AP['SUMCHI2']].drop_duplicates('EVENTNUMBER')
mc_signal_candidates  = mc_data24_selected_chi2[mc_data24_selected_chi2.groupby(['EVENTNUMBER']).transform('max','p_PID_P')['p_PID_P']==mc_data24_selected_chi2['p_PID_P']].drop_duplicates()

data24_selected_chi2  = data24_AP[data24_AP.groupby(['EVENTNUMBER']).transform('min','SUMCHI2')['SUMCHI2']==data24_AP['SUMCHI2']].drop_duplicates('EVENTNUMBER')
data24_candidates  = data24_selected_chi2[data24_selected_chi2.groupby(['EVENTNUMBER']).transform('max','p_PID_P')['p_PID_P']==data24_selected_chi2['p_PID_P']].drop_duplicates()

# %%
mc_signal_candidates.to_pickle('mc_data_candidates.pkl')

data24_candidates.to_pickle('data24_candidates.pkl')
